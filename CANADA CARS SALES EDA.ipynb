# %% [markdown]
# # CANADA CARS SALES EDA
# * CANADA CARS SALES FIGURES (2019-2021)

# %% [markdown]
# ## Import required library

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)

# %%
car_sale = pd.read_csv('Canadasalesdata.csv')

# %%
car_sale
# Out:
#                   Model  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Acura MDX   93  389   782   611   550   501     0     0     0
# 1               Audi Q7  210  210   236   303   292   303     0     0     0
# 2               Audi Q8  130  130   146   211   203   211     0     0     0
# 3                BMW X5  323  323   364   518   498   518     0     0     0
# 4                BMW X6   72   72    81   113   108   113     0     0     0
# ..                  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 231      Subaru Outback  499  621   948  1065  1079   981  1074   845   644
# 232      Toyota 4Runner  605  393   784   762   854   681   824   903   522
# 233   Toyota Highlander  729  792  1184  1095  1185  1423  1347  1336  1114
# 234    Volkswagen Atlas  530  521   822   925   881   725   761   769   748
# 235  Volkswagen Touareg    7    2     5     2     1     3     2     0     1
#
#       Oct   Nov   Dec  Sumofsales Category  Year
# ...

# %% [markdown]
# ## Data analysing

# %%
# this operation done for prints information about the DataFrame
car_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Model       236 non-null    object
#  1   Jan         236 non-null    int64
#  2   Feb         236 non-null    int64
#  3   Mar         236 non-null    int64
#  4   Apr         236 non-null    int64
#  5   May         236 non-null    int64
#  6   Jun         236 non-null    int64
#  7   Jul         236 non-null    int64
#  8   Aug         236 non-null    int64
#  9   Sep         236 non-null    int64
#  10  Oct         236 non-null    int64
#  11  Nov         236 non-null    int64
#  12  Dec         236 non-null    int64
#  13  Sumofsales  236 non-null    int64
#  14  Category    236 non-null    object
#  15  Year        236 non-null    int64
# dtypes: int64(14), object(2)
# memory usage: 29.6+ KB

# %%
# descriptive statistics that summarize the central tendency, dispersion and shape of dataset
car_sale.describe()
# Out:
#                Jan          Feb          Mar          Apr          May  \
# count   236.000000   236.000000   236.000000   236.000000   236.000000
# mean    257.012712   311.398305   322.682203   313.008475   363.127119
# std     282.639677   411.088459   393.510027   422.197181   443.998266
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      76.750000    81.500000    71.250000    57.750000    80.750000
# 50%     152.500000   188.000000   182.500000   163.000000   198.500000
# 75%     331.500000   389.750000   401.750000   342.250000   477.250000
# max    1639.000000  3165.000000  2568.000000  2510.000000  2701.000000
#
#                Jun          Jul          Aug          Sep          Oct  \
# count   236.000000   236.000000   236.000000   236.000000   236.000000
# mean    364.881356   331.275424   292.004237   281.559322   286.563559
# std     444.153484   478.484243   446.868304   425.216361   434.260820
# ...

# %%
# shape of dataset
car_sale.shape
# Out:
# (236, 16)

# %%
#size of dataset
car_sale.size
# Out:
# 3776

# %%
# checking all columns of dataframe
car_sale.columns
# Out:
# Index(['Model', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'Sumofsales', 'Category', 'Year'],
#       dtype='object')

# %%
# top 5 rows
car_sale.head()
# Out:
#        Model  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  \
# 0  Acura MDX   93  389  782  611  550  501    0    0    0    0    0    0
# 1    Audi Q7  210  210  236  303  292  303    0    0    0    0    0    0
# 2    Audi Q8  130  130  146  211  203  211    0    0    0    0    0    0
# 3     BMW X5  323  323  364  518  498  518    0    0    0    0    0    0
# 4     BMW X6   72   72   81  113  108  113    0    0    0    0    0    0
#
#    Sumofsales Category  Year
# 0        2926      MLS  2021
# 1        1554      MLS  2021
# 2        1031      MLS  2021
# 3        2544      MLS  2021
# 4         559      MLS  2021

# %%
# bottom 5 rows
car_sale.tail()
# Out:
#                   Model  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 231      Subaru Outback  499  621   948  1065  1079   981  1074   845   644
# 232      Toyota 4Runner  605  393   784   762   854   681   824   903   522
# 233   Toyota Highlander  729  792  1184  1095  1185  1423  1347  1336  1114
# 234    Volkswagen Atlas  530  521   822   925   881   725   761   769   748
# 235  Volkswagen Touareg    7    2     5     2     1     3     2     0     1
#
#       Oct   Nov   Dec  Sumofsales Category  Year
# 231   926  1184  1106       10972       MS  2019
# 232   690   663   549        8230       MS  2019
# 233  1366  1316   924       13811       MS  2019
# 234   933   695   601        8911       MS  2019
# 235     3     0     0          26       MS  2019

# %% [markdown]
# ## Data inspection

# %%
# checking null values in every column
car_sale.isnull().sum()
# Out:
# Model         0
# Jan           0
# Feb           0
# Mar           0
# Apr           0
# May           0
# Jun           0
# Jul           0
# Aug           0
# Sep           0
# Oct           0
# Nov           0
# Dec           0
# Sumofsales    0
# Category      0
# Year          0
# dtype: int64

# %% [markdown]
# there is no any null value

# %%
# checking total values in every category
print(car_sale['Category'].value_counts())
print(car_sale['Category'].value_counts(normalize  = True))
# Out:
# MLS    65
# MS     62
# SLS    61
# LLS    27
# LS     21
# Name: Category, dtype: int64
# MLS    0.275424
# MS     0.262712
# SLS    0.258475
# LLS    0.114407
# LS     0.088983
# Name: Category, dtype: float64

# %%
print(car_sale['Year'].value_counts())
print(car_sale['Year'].value_counts(normalize  = True))
# Out:
# 2020    87
# 2019    79
# 2021    70
# Name: Year, dtype: int64
# 2020    0.368644
# 2019    0.334746
# 2021    0.296610
# Name: Year, dtype: float64

# %%
print(car_sale['Model'].value_counts())
# Out:
# Land Rover Range Rover Evoque    4
# Volvo XC60                       4
# Volvo XC40                       4
# Mercedes0Benz GLC/GLK0Class      4
# Mercedes0Benz GLA0Class          4
# Lincoln MKC                      4
# Alfa Romeo Stelvio               4
# Audi eTron                       4
# Audi Q3                          4
# Audi Q5                          4
# BMW X1                           4
# BMW X2                           4
# Cadillac XT4                     4
# Lexus UX                         4
# Infiniti QX50                    4
# Jaguar E0Pace                    4
# Land Rover Discovery Sport       4
# Lexus NX                         4
# Infiniti QX30                    3
# Kia Telluride                    3
# Kia Sorento                      3
# BMW X7                           3
# Cadillac Escalade                3
# Infiniti QX80                    3
# Land Rover Range Rover           3
# Lexus LX                         3
# Lincoln Navigator                3
# ...

# %% [markdown]
# #### all value_count operation done for checking values in every category

# %% [markdown]
# ### Checking  outliers

# %%
# plotting boxplot for cheking outliers
sns.boxplot(car_sale.Sumofsales)
# Out:
# <AxesSubplot:xlabel='Sumofsales'>

# %%
# checking amount of outliers are present in series 
outliers = car_sale.Sumofsales[(car_sale.Sumofsales > 10000) & (car_sale.Sumofsales < 21000)]
outliers.size
# Out:
# 20

# %%
a = car_sale['Sumofsales'].replace(car_sale['Sumofsales']>9000)
a.value_counts()
# Out:
# False    14
# 2507      2
# 1788      2
# 458       2
# 490       2
#          ..
# 8048      1
# 2384      1
# 790       1
# 3498      1
# 8911      1
# Name: Sumofsales, Length: 204, dtype: int64

# %% [markdown]
# ### Handling outliers

# %%
# The lines of code print the 10th and 90th percentiles of the variable 'Sumofsales', respectively. 
# These values will be used for quantile-based flooring and capping.

print(car_sale['Sumofsales'].quantile(0.10))
print(car_sale['Sumofsales'].quantile(0.90))
# Out:
# 332.5
# 9495.0

# %%
car_sale['Sumofsales'] = np.where(car_sale['Sumofsales'] <332.5, 332.5,car_sale['Sumofsales'])
car_sale['Sumofsales'] = np.where(car_sale['Sumofsales'] >9495.0, 9495.0,car_sale['Sumofsales'])
print(car_sale['Sumofsales'].skew())
# Out:
# 1.1127771603305112

# %%
# updated boxplot after working on outliers
sns.boxplot(car_sale.Sumofsales)
# Out:
# <AxesSubplot:xlabel='Sumofsales'>

# %% [markdown]
# # Univariate Analysis

# %%
car_sale.head()
# Out:
#        Model  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  \
# 0  Acura MDX   93  389  782  611  550  501    0    0    0    0    0    0
# 1    Audi Q7  210  210  236  303  292  303    0    0    0    0    0    0
# 2    Audi Q8  130  130  146  211  203  211    0    0    0    0    0    0
# 3     BMW X5  323  323  364  518  498  518    0    0    0    0    0    0
# 4     BMW X6   72   72   81  113  108  113    0    0    0    0    0    0
#
#    Sumofsales Category  Year
# 0      2926.0      MLS  2021
# 1      1554.0      MLS  2021
# 2      1031.0      MLS  2021
# 3      2544.0      MLS  2021
# 4       559.0      MLS  2021

# %% [markdown]
# ## For Continuous Variables

# %% [markdown]
# ### distribution of sum of sales

# %%
car_sale.Sumofsales.plot(kind = 'hist', grid = True )
plt.show()

# %% [markdown]
# ### For Categorical Variables :

# %%
car_sale.groupby('Year').Sumofsales.sum().plot(kind='pie',shadow = True, autopct = '%1.01f%%')
plt.show()
print(car_sale.groupby('Year').sum()['Sumofsales'])
# Out:
# Year
# 2019    322527.0
# 2020    294202.5
# 2021    134844.5
# Name: Sumofsales, dtype: float64

# %% [markdown]
# ### As per above operation we can see 2019 has highest sale

# %%
car_sale.groupby('Category').Sumofsales.sum().plot(kind='pie',shadow = True, autopct = '%1.01f%%')
plt.show()
print(car_sale.groupby('Category').Sumofsales.sum())
# Out:
# Category
# LLS     30168.0
# LS      40480.0
# MLS    149584.5
# MS     376600.0
# SLS    154741.5
# Name: Sumofsales, dtype: float64

# %% [markdown]
# ### Asper above operation we can see ms model has highest sale

# %%
sns.countplot(car_sale.Category)
plt.show()

# %%
car_sale.groupby('Year').Sumofsales.sum().plot(kind='bar')
plt.show()

# %% [markdown]
# # Bivariate Analysis
# Numerical & Numerical: To see the relationship between the 2 variables we create Scatter Plots and a Correlation Matrix with a Heatmap on the top.

# %%
car_sale.head()
# Out:
#        Model  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec  \
# 0  Acura MDX   93  389  782  611  550  501    0    0    0    0    0    0
# 1    Audi Q7  210  210  236  303  292  303    0    0    0    0    0    0
# 2    Audi Q8  130  130  146  211  203  211    0    0    0    0    0    0
# 3     BMW X5  323  323  364  518  498  518    0    0    0    0    0    0
# 4     BMW X6   72   72   81  113  108  113    0    0    0    0    0    0
#
#    Sumofsales Category  Year
# 0      2926.0      MLS  2021
# 1      1554.0      MLS  2021
# 2      1031.0      MLS  2021
# 3      2544.0      MLS  2021
# 4       559.0      MLS  2021

# %%
car_sale.plot(x='Jan',y='Sumofsales',kind = 'scatter')
plt.show()

# %%
# Plotting Regression plot for Sumofsales vs Dec
plt.figure(figsize=(15,8),dpi=150)
sns.regplot(data=car_sale,y='Sumofsales',x='Dec')
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
car_sale.select_dtypes([int,float]).corr()
# Out:
#                  Jan       Feb       Mar       Apr       May       Jun  \
# Jan         1.000000  0.911420  0.862278  0.763553  0.836325  0.850587
# Feb         0.911420  1.000000  0.791454  0.670612  0.776681  0.795464
# Mar         0.862278  0.791454  1.000000  0.942217  0.917571  0.894250
# Apr         0.763553  0.670612  0.942217  1.000000  0.898189  0.857343
# May         0.836325  0.776681  0.917571  0.898189  1.000000  0.940355
# Jun         0.850587  0.795464  0.894250  0.857343  0.940355  1.000000
# Jul         0.804367  0.808607  0.773425  0.660126  0.830526  0.825513
# Aug         0.722141  0.726164  0.658710  0.563751  0.761814  0.716540
# Sep         0.785975  0.770444  0.623503  0.513144  0.668264  0.668549
# Oct         0.749385  0.695903  0.560162  0.454281  0.594869  0.590940
# Nov         0.699191  0.648352  0.565717  0.468388  0.588042  0.549120
# Dec         0.671433  0.632725  0.428254  0.289500  0.474508  0.546415
# ...

# %%
plt.figure(figsize=(15,8),dpi=150)
sns.heatmap(car_sale.select_dtypes(['float64' , 'int64']).corr(),annot=True)
plt.show()

# %% [markdown]
# ### As per heatmap
# * oct-nov:  0.96
# * may-jun:  0.94
# * mar-apr:  0.94
#
# has highest correlations
